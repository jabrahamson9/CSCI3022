# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jcabr\OneDrive\Documents\Issys Shit\dads.csv")
df.head()
# Out:
#   Period  Account  Major  acct   Account Name Cost Center  \
# 0     Q1  800..01        800.0  COMPANY LABOR  1CO0761110
# 1     Q1  800..01        800.0  COMPANY LABOR  1CO0761124
# 2     Q1  800..01        800.0  COMPANY LABOR  1CO0761154
# 3     Q1  800..01        800.0  COMPANY LABOR  1CO0761162
# 4     Q1  800..01        800.0  COMPANY LABOR  1CO0761170
#
#           Cost center name           API Project JIB dk/sess Vendor Name  \
# 0       RAZOR 33P-3313 BPO  05-123-40216             22464,4
# 1  COTTONWOOD 08E-0504 BPO  05-123-40408             19791,2
# 2  RAZOR FEDERAL 12F-1301A  05-123-38709             22997,1
# 3          RAZOR 12F-0101A  05-123-38713             22979,2
# 4      RAZOR 10E-0302B BPO  05-123-40049             22534,2
#
#   Vendor no Inv No Source document    Voucher no. Image ref Acctg period  \
# 0                    1*1602-JE-276  1*1602-JE-276                 Feb-16
# 1                    1*1602-JE-276  1*1602-JE-276                 Feb-16
# ...

# %%
len(df)
# Out:
# 23144

# %%
df = df.rename(columns={"Inv No": "InvNo"})
# df = df.dropna(subset=["InvNo"] )
df = df[df.InvNo != ' ']
df.head()
# Out:
#     Period  Account  Major  acct     Account Name Cost Center  \
# 589     Q1  800..03        800.0  CONTRACT PUMPER   1CO080800
# 590     Q1  800..03        800.0  CONTRACT PUMPER  1CO0761228
# 591     Q1  800..03        800.0  CONTRACT PUMPER  1CO0761191
# 592     Q1  800..03        800.0  CONTRACT PUMPER  1CO0761224
# 593     Q1  800..03        800.0  CONTRACT PUMPER  1CO0761225
#
#            Cost center name           API Project JIB dk/sess  \
# 589      KERNDT 43-33 (P&A)  05-123-10268             13117,1
# 590      RAZOR 29F-2007 BPO  05-123-40411             22925,1
# 591      RAZOR 08E-1704 BPO  05-123-41491             22780,1
# 592  RAZOR FED 30K-1907 BPO  05-123-40209             22821,2
# 593  RAZOR FED 30K-1908 BPO  05-123-40212             22822,2
#
#              Vendor Name Vendor no      InvNo  Source document  \
# 589     TIMOTHY R GINTER     83942  PMPR.1.77  83942*PMPR.1.77
# 590  SELECT WELL SERVICE     93261   SI970220   93261*SI970220
# ...

# %%
len(df)
# Out:
# 17236

# %%
df = df.drop_duplicates(subset = ["InvNo"])
df.head()
# Out:
#     Period  Account  Major  acct     Account Name Cost Center  \
# 589     Q1  800..03        800.0  CONTRACT PUMPER   1CO080800
# 590     Q1  800..03        800.0  CONTRACT PUMPER  1CO0761228
# 598     Q1  800..06        800.0       ELECTRICAL   1CO076974
# 683     Q1  800..06        800.0       ELECTRICAL  1CO0761085
# 756     Q1  800..07        800.0             FUEL  1CO0761224
#
#            Cost center name           API Project JIB dk/sess  \
# 589      KERNDT 43-33 (P&A)  05-123-10268             13117,1
# 590      RAZOR 29F-2007 BPO  05-123-40411             22925,1
# 598   PAWNEE CREEK 9-57-18H  05-123-33752             15923,1
# 683      RAZOR 21C-0905 BPO  05-123-39525             19494,3
# 756  RAZOR FED 30K-1907 BPO  05-123-40209             22821,2
#
#                       Vendor Name Vendor no        InvNo   Source document  \
# 589              TIMOTHY R GINTER     83942    PMPR.1.77   83942*PMPR.1.77
# ...

# %%
len(df)
# Out:
# 472

# %%
df.to_excel(r"C:\Users\jcabr\OneDrive\Documents\Issys Shit\cleaned.xlsx")
